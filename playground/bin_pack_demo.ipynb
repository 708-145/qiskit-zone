# %% [markdown]
# ## Introduction
#
# There a many ways how to approach programming a quantum computer. The two extreme cases are
# * manual development of an algorithm for each problem. This is similar to how code for HPC is developed, highly customized and highly specialized for each problem with high effort
# * use a high level compiler to transform an abstract high level description of the problem to a machine executable form. One example of that is Mathematical Programming which is implemented by IBM CPLEX classically (so far only convex problems).
#
# Let's use here what Qiskit provides since the Aqua 0.7.0 release:
#
# Qiskit introduces the `QuadraticProgram` class to make a model of an optimization problem.
# More precicely, it deals with quadratically constrained quadratic programs given as follows:
#
# $$
# \begin{align}
# \text{minimize}\quad& x^\top Q_0 x + c^\top x\\
# \text{subject to}\quad& A x \leq b\\
# & x^\top Q_i x + a_i^\top x \leq r_i, \quad 1,\dots,i,\dots,q\\
# & l_i \leq x_i \leq u_i, \quad 1,\dots,i,\dots,n,
# \end{align}
# $$
#
# where the $Q_i$ are $n \times n$ matrices, $A$ is a $m \times n$ matrix , $x$, and $c$ are $n$-dimensional vectors, $b$ is an $m$-dimensional vector, and where $x$ can defined as binary, integer, or continuous variables.
# In addition to "$\leq$" constraints 'QuadraticProgram' also supports "$\geq$" and "$=$".

# %%
# useful additional packages 
import matplotlib.pyplot as plt
import matplotlib.axes as axes
# %matplotlib inline
import numpy as np
import networkx as nx
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
# Loading your IBM Q account(s)
#provider = IBMQ.load_account()
# DOcplex
from docplex.mp.model import Model
# Aqua
from qiskit import BasicAer
from qiskit.optimization import QuadraticProgram
from qiskit.optimization.converters import QuadraticProgramToIsing, InequalityToEquality, IntegerToBinary, LinearEqualityToPenalty
from qiskit.optimization.algorithms import MinimumEigenOptimizer, RecursiveMinimumEigenOptimizer
from qiskit.aqua.algorithms import QAOA, VQE, ExactEigensolver, NumPyMinimumEigensolver
#from qiskit.aqua.components.optimizers import SPSA
#from qiskit.aqua.components.variational_forms import RY
#from qiskit.aqua import QuantumInstance
# setup aqua logging
import logging
from qiskit.aqua import set_qiskit_aqua_logging
set_qiskit_aqua_logging(logging.DEBUG)  # choose INFO, DEBUG to see the log
#provider = IBMQ.get_provider(hub='ibm-q')

# %% [markdown]
# ## Example
#
# Here we use bin packing as an example problem. It's intentionally kept small and simple to concentrate on the workflow below.
#
# Just insert any other more complex model here and reuse the transformation and solver steps below.

# %%
# Create an instance of a model and variables
mdl = Model(name='bin_pack')
x = {i: mdl.binary_var(name='x_{0}'.format(i)) for i in range(1,4)}

# Objective function
max_vars_func = mdl.sum(x[i] for i in range(1,4))
mdl.maximize(max_vars_func)

# Constraints
weight = [2, 4, 6]
mdl.add_constraint(mdl.sum(weight[i-1]*x[i] for i in range(1,4)) == 10)

print(mdl.export_to_string())
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: bin_pack
#
# Maximize
#  obj: x_1 + x_2 + x_3
# Subject To
#  c1: 2 x_1 + 4 x_2 + 6 x_3 = 10
#
# Bounds
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#
# Binaries
#  x_1 x_2 x_3
# End

# %%
# load QuadraticProgram from a Docplex model
qp = QuadraticProgram()
qp.from_docplex(mdl)
print(qp.export_as_lp_string())
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: bin_pack
#
# Maximize
#  obj: x_1 + x_2 + x_3
# Subject To
#  c0: 2 x_1 + 4 x_2 + 6 x_3 = 10
#
# Bounds
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#
# Binaries
#  x_1 x_2 x_3
# End

# %%
# convert inequalities to equalities using slack variables
ineq2eq = InequalityToEquality()
qp_eq = ineq2eq.encode(qp)
print(qp_eq.export_as_lp_string())
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: bin_pack
#
# Maximize
#  obj: x_1 + x_2 + x_3
# Subject To
#  c0: 2 x_1 + 4 x_2 + 6 x_3 = 10
#
# Bounds
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#
# Binaries
#  x_1 x_2 x_3
# End

# %%
# move all conditions to the objective function ("penalty")
lineq2penalty = LinearEqualityToPenalty()
qubo = lineq2penalty.encode(qp_eq)
print(qubo.export_as_lp_string())
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: bin_pack
#
# Maximize
#  obj: 4000001 x_1 + 8000001 x_2 + 12000001 x_3 + [ - 800000 x_1^2
#       - 3200000 x_1*x_2 - 4800000 x_1*x_3 - 3200000 x_2^2 - 9600000 x_2*x_3
#       - 7200000 x_3^2 ]/2 -10000000
# Subject To
#
# Bounds
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#
# Binaries
#  x_1 x_2 x_3
# End

# %% [markdown]
# ## Solvers
#
# Now that we finally prepared the Quadratic Program for the problem at hand, we have several options to solve it.
#
# One family of solvers is reused from other quantum computing problem domains, in the case of VQE (Variational Quantum Eigensolver) and QAOA (Quantum Approximate Optimization Algorithm) mostly quantum chemistry.
# The idea here is to convert the Quadratic Program into an Ising Hamiltonian and find the minimum Eigenvector.
# That Eigenvector represents the optimal solution to the Quadratic Program.
#
# Another recent family is based on Grover Search. GAS (Grover Adaptive Search) is provided in the form of `GroverOptimizer`.
#
# An extension to binary 'QUBO' problems is the mixed-binary problem class called 'MBCO'. See "3-ADMM-H" for details.

# %%
# convert to Ising Hamiltonian to be able to search for minimum eigenvector later
qp2op = QuadraticProgramToIsing()
op, offset = qp2op.encode(qubo)
print('offset: {}'.format(offset))
print('operator:')
print(op.print_details())
# Out:
# offset: 2999998.5
# operator:
# IIZ	(800000.5+0j)
# IZI	(1600000.5+0j)
# ZII	(2400000.5+0j)
# IZZ	(400000+0j)
# ZIZ	(600000+0j)
# ZZI	(1200000+0j)

# %%
qaoa_mes = QAOA(quantum_instance=BasicAer.get_backend('statevector_simulator'))
exact_mes = NumPyMinimumEigensolver()

qaoa = MinimumEigenOptimizer(qaoa_mes)   # using QAOA
exact = MinimumEigenOptimizer(exact_mes)  # using the exact classical numpy minimum eigen solver
# Out:
# 2020-06-15 09:29:33,879:qiskit.aqua.quantum_instance:INFO: statevector backend only works with shot=1, change shots from 1024 to 1.
# 2020-06-15 09:29:33,881:qiskit.aqua.quantum_instance:INFO:
# Qiskit Terra version: 0.14.1
# Backend: 'statevector_simulator (BasicAer)', with following setting:
# {'basis_gates': ['u1', 'u2', 'u3', 'cx', 'id', 'unitary'], 'coupling_map': None}
# {'pass_manager': None, 'initial_layout': None, 'seed_transpiler': None, 'optimization_level': None}
# RunConfig(max_credits=10, shots=1)
# {'timeout': None}
# {}
# {}
# Measurement mitigation: None
# 2020-06-15 09:29:33,883:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO:
# ==================== Setting of QAOA ============================
# Algorithm: QAOA
# -- p: 1
# -- mixer_operator: None
# -- initial_state: None
# -- max_evals_grouped: 1
# -- circuit_sampler: <qiskit.aqua.operators.converters.circuit_sampler.CircuitSampler object at 0x000001B494DCFF48>
# -- expectation: None
# -- expect_op: None
# -- operator: None
# -- quantum_instance:
# Qiskit Terra version: 0.14.1
# Backend: 'statevector_simulator (BasicAer)', with following setting:
# {'basis_gates': ['u1', 'u2', 'u3', 'cx', 'id', 'unitary'], 'coupling_map': None}
# {'pass_manager': None, 'initial_layout': None, 'seed_transpiler': None, 'optimization_level': None}
# RunConfig(max_credits=10, shots=1)
# {'timeout': None}
# {}
# {}
# Measurement mitigation: None
# -- optimizer: <qiskit.aqua.components.optimizers.slsqp.SLSQP object at 0x000001B494DD9988>
# -- cost_fn: <bound method VQE._energy_evaluation of <qiskit.aqua.algorithms.minimum_eigen_solvers.qaoa.qaoa.QAOA object at 0x000001B494DD99C8>>
# -- initial_point: Random seed
# -- var_form: None
# -- var_form_params: None
# -- parameterized_circuits: None
# -- ret: None
# -- eval_time: None
# -- callback: None
# -- aux_op_nones: None
# -- aux_operators: None
# -- eval_count: 0
# ===============================================================
# var_form has not been set===============================================================
# Optimizer: SLSQP
# -- gradient_support_level: 2
# -- bounds_support_level: 2
# -- initial_point_support_level: 3
# -- options: {'maxiter': 100, 'disp': False, 'ftol': 1e-06, 'eps': 1.4901161193847656e-08}
# -- max_evals_grouped: 1
# -- tol: None
# ===============================================================

# %%
exact_result = exact.solve(qubo)
print(exact_result)
# Out:
# 2020-06-15 09:29:34,551:qiskit.aqua.algorithms.eigen_solvers.numpy_eigen_solver:DEBUG: NumPyEigensolver _run result:
# {   'eigvals': array([-3000000.5+0.j]),
#     'eigvecs': array([[0., 0., 0., 0., 0., 0., 1., 0.]]),
#     'energies': array([-3000000.5]),
#     'energy': -3000000.5,
#     'wavefunction': array([[0., 0., 0., 0., 0., 0., 1., 0.]])}
# 2020-06-15 09:29:34,553:qiskit.aqua.algorithms.eigen_solvers.numpy_eigen_solver:DEBUG: EigensolverResult dict:
# {   'eigenstates': ListOp([VectorStateFn(Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2)), coeff=1.0, is_measurement=False)], coeff=1.0, abelian=False),
#     'eigenvalues': array([-3000000.5+0.j])}
# 2020-06-15 09:29:34,555:qiskit.aqua.algorithms.minimum_eigen_solvers.numpy_minimum_eigen_solver:DEBUG: NumPyMinimumEigensolver dict:
# {   'eigenstate': VectorStateFn(Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2)), coeff=1.0, is_measurement=False),
#     'eigenvalue': (-3000000.5+0j)}
# x=[0.0,1.0,1.0], fval=2.0

# %%
qaoa_result = qaoa.solve(qubo)
print(qaoa_result)
# Out:
# 2020-06-15 09:29:34,960:qiskit.aqua.algorithms.vq_algorithm:INFO: Starting optimizer.
# bounds=[(0, 3.141592653589793), (0, 6.283185307179586)]
# initial point=[0.24482771 3.38704559]
# 2020-06-15 09:29:35,157:qiskit.aqua.quantum_instance:DEBUG: ==== Before transpiler ====
# 2020-06-15 09:29:35,157:qiskit.aqua.quantum_instance:DEBUG: Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 3 qubits, 0 classical bits and 18 operations with depth 12
# op_counts: OrderedDict([('cx', 6), ('rz', 6), ('h', 3), ('rx', 3)])
# ============================================================================
#
# 2020-06-15 09:29:35,158:qiskit.aqua.quantum_instance:DEBUG: ====  After transpiler ====
# 2020-06-15 09:29:35,158:qiskit.aqua.quantum_instance:DEBUG: Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 3 qubits, 0 classical bits and 18 operations with depth 12
# op_counts: OrderedDict([('cx', 6), ('u1', 6), ('u2', 3), ('u3', 3)])
# ============================================================================
#
# 2020-06-15 09:29:35,176:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [-259548.66219606] - 21.94214 (ms), eval count: 1
# 2020-06-15 09:29:35,180:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [-259548.66219606] - 2.96259 (ms), eval count: 2
# 2020-06-15 09:29:35,187:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [-258188.20432312] - 5.95045 (ms), eval count: 3
# 2020-06-15 09:29:35,192:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [-259548.67825822] - 4.02236 (ms), eval count: 4
# 2020-06-15 09:29:35,193:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Optimization complete in 0.23252606391906738 seconds.
# Found opt_params [0.24482771 3.38704559] in 4 evals
# x=[0.0,1.0,1.0], fval=2.0

# %% [markdown]
# ## Improvements
#
# ### convenience:
#
# The usability and convenience has been improved lately by supporting models with
# * linear and quadratic equations
# * equalities and inequalities
# * binary and integer variables
#
# Most of these improvements of scope have been paid for in the number of qubits (slack variables, int approximation).
# This makes the representation less compact and with that less fit for near term Quantum Computers.
#
#
# ### depth:
#
# Recursive solvers are introduced to limit the Quantum Circuit depth.
# The circuit is iteratively refined and executed many times.
# Qiskit provides this via `RecursiveMinimumEigenOptimizer`.
#
# ### scope:
#
# * Binary optimization (QUBO): On top of Ising based solvers, Grover based solvers (`GroverOptimizer`) have been recently introduced.
# * Mixed-binary optimization (MBCO): The ADMM Optimizer can solve classes of mixed-binary constrained optimization problems
# * Mixed-integer methods are still missing.
#
# ### width:
#
# Future research is needed on hybrid solvers that process hard and compact subproblems on the Quantum Computer and combine this via classical solvers to the final solution.

# %%
# Example of the usage of the recursive solver
rqaoa = RecursiveMinimumEigenOptimizer(min_eigen_optimizer=qaoa, min_num_vars=1, min_num_vars_optimizer=exact)
rqaoa_result = rqaoa.solve(qubo)
print(rqaoa_result)
# Out:
# 2020-06-15 14:44:16,636:qiskit.aqua.algorithms.vq_algorithm:INFO: Starting optimizer.
# bounds=[(0, 3.141592653589793), (0, 6.283185307179586)]
# initial point=[1.1472687  0.63465201]
# 2020-06-15 14:44:16,696:qiskit.aqua.quantum_instance:DEBUG: ==== Before transpiler ====
# 2020-06-15 14:44:16,697:qiskit.aqua.quantum_instance:DEBUG: Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 3 qubits, 0 classical bits and 18 operations with depth 12
# op_counts: OrderedDict([('cx', 6), ('rz', 6), ('h', 3), ('rx', 3)])
# ============================================================================
#
# 2020-06-15 14:44:16,698:qiskit.aqua.quantum_instance:DEBUG: ====  After transpiler ====
# 2020-06-15 14:44:16,700:qiskit.aqua.quantum_instance:DEBUG: Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 3 qubits, 0 classical bits and 18 operations with depth 12
# op_counts: OrderedDict([('cx', 6), ('u1', 6), ('u2', 3), ('u3', 3)])
# ============================================================================
#
# 2020-06-15 14:44:16,711:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [386456.41125059] - 21.39354 (ms), eval count: 1
# 2020-06-15 14:44:16,719:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [386456.41125059] - 7.70807 (ms), eval count: 2
# 2020-06-15 14:44:16,729:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [329602.47501625] - 7.97915 (ms), eval count: 3
# 2020-06-15 14:44:16,739:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [386456.42402994] - 7.28679 (ms), eval count: 4
# 2020-06-15 14:44:16,740:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Optimization complete in 0.10388851165771484 seconds.
# Found opt_params [1.1472687  0.63465201] in 4 evals
# 2020-06-15 14:44:16,996:qiskit.aqua.algorithms.vq_algorithm:INFO: Starting optimizer.
# bounds=[(0, 3.141592653589793), (0, 6.283185307179586)]
# initial point=[0.30056487 1.05226766]
# 2020-06-15 14:44:17,022:qiskit.aqua.quantum_instance:DEBUG: ==== Before transpiler ====
# 2020-06-15 14:44:17,025:qiskit.aqua.quantum_instance:DEBUG: Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 2 qubits, 0 classical bits and 9 operations with depth 6
# op_counts: OrderedDict([('rz', 3), ('h', 2), ('cx', 2), ('rx', 2)])
# ============================================================================
#
# 2020-06-15 14:44:17,029:qiskit.aqua.quantum_instance:DEBUG: ====  After transpiler ====
# 2020-06-15 14:44:17,032:qiskit.aqua.quantum_instance:DEBUG: Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 2 qubits, 0 classical bits and 9 operations with depth 6
# op_counts: OrderedDict([('u1', 3), ('u2', 2), ('cx', 2), ('u3', 2)])
# ============================================================================
#
# 2020-06-15 14:44:17,047:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [-1768482.27230835] - 32.88364 (ms), eval count: 1
# 2020-06-15 14:44:17,061:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [-1768482.27230835] - 11.91807 (ms), eval count: 2
# 2020-06-15 14:44:17,080:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [-1784905.21974712] - 14.96410 (ms), eval count: 3
# 2020-06-15 14:44:17,095:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Energy evaluation returned [-1768482.29122954] - 11.97076 (ms), eval count: 4
# 2020-06-15 14:44:17,098:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:INFO: Optimization complete in 0.10169816017150879 seconds.
# Found opt_params [0.30056487 1.05226766] in 4 evals
# 2020-06-15 14:44:17,209:qiskit.aqua.algorithms.eigen_solvers.numpy_eigen_solver:DEBUG: NumPyEigensolver _run result:
# {   'eigvals': array([-1799999.5+0.j]),
#     'eigvecs': array([[1., 0.]]),
#     'energies': array([-1799999.5]),
#     'energy': -1799999.5,
#     'wavefunction': array([[1., 0.]])}
# 2020-06-15 14:44:17,212:qiskit.aqua.algorithms.eigen_solvers.numpy_eigen_solver:DEBUG: EigensolverResult dict:
# {   'eigenstates': ListOp([VectorStateFn(Statevector([1.+0.j, 0.+0.j],
#             dims=(2,)), coeff=1.0, is_measurement=False)], coeff=1.0, abelian=False),
#     'eigenvalues': array([-1799999.5+0.j])}
# 2020-06-15 14:44:17,213:qiskit.aqua.algorithms.minimum_eigen_solvers.numpy_minimum_eigen_solver:DEBUG: NumPyMinimumEigensolver dict:
# {   'eigenstate': VectorStateFn(Statevector([1.+0.j, 0.+0.j],
#             dims=(2,)), coeff=1.0, is_measurement=False),
#     'eigenvalue': (-1799999.5+0j)}
# x=[0.0,0.0,1.0], fval=-1599999.0

# %%
# Example using GAS `GroverOptimizer`

# %%
IBMQ.providers()    # List all available providers
IBMQ.get_provider(hub='ibm-q')
provider = IBMQ.get_provider(hub='ibm-q')
provider.backends()

# %%
# run quantum algorithm with shots
#seed = 10598
seed = 1

spsa = SPSA(max_trials=300)
ry = RY(qubitOp.num_qubits, depth=5, entanglement='linear')
vqe = VQE(qubitOp, ry, spsa)

#backend = BasicAer.get_backend('qasm_simulator')
backend = provider.get_backend('ibmq_ourense')
quantum_instance = QuantumInstance(backend, shots=1024, seed_simulator=seed, seed_transpiler=seed, skip_qobj_validation=False)

result = vqe.run(quantum_instance)

x = sample_most_likely(result['eigvecs'][0])
print('energy:', result['energy'])
print('time:', result['eval_time'])
print('solution objective:', result['energy'] + offset)
print('solution:', x)

# %%
print("result:", result)
print("eigvec:", result['eigvecs'])
plot_histogram(result['eigvecs'])
#print("circuit_width", result['circuit_info']['width'])
#print("circuit_depth", result['circuit_info']['depth'])

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# %qiskit_copyright
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td>Qiskit</td><td>0.19.1</td></tr><tr><td>Terra</td><td>0.14.1</td></tr><tr><td>Aer</td><td>0.5.1</td></tr><tr><td>Ignis</td><td>0.3.0</td></tr><tr><td>Aqua</td><td>0.7.0</td></tr><tr><td>IBM Q Provider</td><td>0.7.0</td></tr><tr><th>System information</th></tr><tr><td>Python</td><td>3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]</td></tr><tr><td>OS</td><td>Windows</td></tr><tr><td>CPUs</td><td>4</td></tr><tr><td>Memory (Gb)</td><td>31.84252166748047</td></tr><tr><td colspan='2'>Tue May 26 15:07:10 2020 Mitteleuropäische Sommerzeit</td></tr></table>
# <div style='width: 100%; background-color:#d5d9e0;padding-left: 10px; padding-bottom: 10px; padding-right: 10px; padding-top: 5px'><h3>This code is a part of Qiskit</h3><p>&copy; Copyright IBM 2017, 2020.</p><p>This code is licensed under the Apache License, Version 2.0. You may<br>obtain a copy of this license in the LICENSE.txt file in the root directory<br> of this source tree or at http://www.apache.org/licenses/LICENSE-2.0.<p>Any modifications or derivative works of this code must retain this<br>copyright notice, and modified files need to carry a notice indicating<br>that they have been altered from the originals.</p></div>
